# %% [markdown]
# <a href="https://colab.research.google.com/github/Amruda-glitch/Hands-on-Training/blob/main/Working_with_Langchain%2C_Transformer_and_RAG_concepts.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U langchain langchain_community

# %%
# !pip install langchain groq faiss-cpu sentence-transformers tiktoken

# %%
# !pip install langchain langchain-community langchain-groq faiss-cpu pypdf
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 346.6/346.6 kB 8.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 kB 12.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: groq
#     Found existing installation: groq 1.4.0
#     Uninstalling groq-1.4.0:
#       Successfully uninstalled groq-1.4.0
# ...

# %%
from langchain_community.document_loaders import TextLoader
from langchain_text_splitters import CharacterTextSplitter
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import FAISS
from langchain_groq import ChatGroq
from langchain_classic.chains import RetrievalQA
import os

# %%
loader= TextLoader('/content/drive/MyDrive/sample.txt')
documents = loader.load()

# %%
splitter = CharacterTextSplitter(chunk_size=500,chunk_overlap=50)
docs=splitter.split_documents(documents)
# Out:
# WARNING:langchain_text_splitters.base:Created a chunk of size 511, which is longer than the specified 500
