# %% [markdown]
# <a href="https://colab.research.google.com/github/Amruda-glitch/Hands-on-Training/blob/main/Computer_Vision_using_Edge_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import numpy as np
cv2.__version__
# Out:
# '4.13.0'

# %%
img1=cv2.imread("/content/drive/MyDrive/HP.avif")

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img1)
# Out:
# <PIL.Image.Image image mode=RGB size=980x1103>

# %%
gray_image=cv2.cvtColor(img1,cv2.COLOR_BGR2GRAY)
edges=cv2.Canny(gray_image,50,140)
from google.colab.patches import cv2_imshow
cv2_imshow(edges)
# Out:
# <PIL.Image.Image image mode=L size=980x1103>
